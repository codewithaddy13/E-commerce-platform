# %%
import pandas as pd


df = pd.read_csv('mobileprices.csv')
df
# Out:
#        Brand              Model Storage    RAM  Screen Size (inches)  \
# 0      Apple      iPhone 13 Pro   128 GB   6 GB                  6.1
# 1    Samsung   Galaxy S21 Ultra   256 GB  12 GB                  6.8
# 2    OnePlus              9 Pro   128 GB   8 GB                  6.7
# 3     Xiaomi  Redmi Note 10 Pro   128 GB   6 GB                 6.67
# 4     Google            Pixel 6   128 GB   8 GB                  6.4
# ..       ...                ...      ...    ...                  ...
# 402  Samsung   Galaxy Note20 5G      128      8                  6.7
# 403   Xiaomi      Mi 10 Lite 5G      128      6                 6.57
# 404    Apple  iPhone 12 Pro Max      128      6                  6.7
# 405     Oppo              Reno3      128      8                  6.4
# 406  Samsung    Galaxy S10 Lite      128      6                  6.7
#
#             Camera (MP)  Battery Capacity (mAh) Price ($)
# 0          12 + 12 + 12                    3095       999
# ...

# %%
df.shape
# Out:
# (407, 8)

# %%
df[df.duplicated()]
# Out:
#         Brand                  Model Storage   RAM  Screen Size (inches)  \
# 45      Apple         iPhone 12 Mini    64 GB  4 GB                  5.4
# 61     Xiaomi         Poco M3 Pro 5G    64 GB  4 GB                  6.5
# 132     Nokia                   XR20    128GB   6GB                 6.67
# 170  Motorola       Moto G Stylus 5G    128GB   5GB                  6.8
# 195      Oppo                 A74 5G    128GB   6GB                  6.5
# 221      Vivo                   Y12s     32GB   3GB                 6.51
# 229    Xiaomi  Redmi Note 10 Pro Max    128GB   8GB                 6.67
# 240     Nokia               C20 Plus     32GB   3GB                  6.5
# 246    Xiaomi            Poco X3 Pro    128GB   6GB                 6.67
# 248      Oppo                    A16     32GB   3GB                 6.52
# 260      Vivo                   Y12s     32GB   3GB                 6.51
# 282   Samsung             Galaxy A12     64GB   4GB                  6.5
# ...

# %%
df.duplicated().sum()
# Out:
# 26

# %%
df.columns
# Out:
# Index(['Brand', 'Model', 'Storage ', 'RAM ', 'Screen Size (inches)',
#        'Camera (MP)', 'Battery Capacity (mAh)', 'Price ($)'],
#       dtype='object')

# %%
df['Screen Size (inches)'].unique()
# Out:
# array(['6.1', '6.8', '6.7', '6.67', '6.4', '6.55', '6.78', '6.43', '6.5',
#        '6.62', '5.4', '6.2', '6.51', '6.6', '4.7', '6.58', '6.52', '6.44',
#        '6.53', '6.56', '6.8 + 3.9', '4.5', '6.39', '5.9', '5.5', '6.81',
#        '5.99', '6.82', '6.3', '6.22', '6', '6.35', '6.9', '6.76', '6.49',
#        '6.72', '5.7', '6.47', '7.6 (unfolded)', '6.15', '6.57'],
#       dtype=object)

# %%
df[df['Screen Size (inches)'] == '7.6 (unfolded)']
# Out:
#        Brand              Model Storage  RAM  Screen Size (inches)  \
# 373  Samsung  Galaxy Z Fold2 5G      256   12       7.6 (unfolded)
#
#     Camera (MP)  Battery Capacity (mAh) Price ($)
# 373    12+12+12                    4500      1999

# %%
df['screen_size(inches)'] = df['Screen Size (inches)'].apply(lambda x : float(x.split(' ')[0]))
df = df.drop('Screen Size (inches)', axis="columns")
df
# Out:
#        Brand              Model Storage    RAM          Camera (MP)  \
# 0      Apple      iPhone 13 Pro   128 GB   6 GB        12 + 12 + 12
# 1    Samsung   Galaxy S21 Ultra   256 GB  12 GB  108 + 10 + 10 + 12
# 2    OnePlus              9 Pro   128 GB   8 GB     48 + 50 + 8 + 2
# 3     Xiaomi  Redmi Note 10 Pro   128 GB   6 GB      64 + 8 + 5 + 2
# 4     Google            Pixel 6   128 GB   8 GB           50 + 12.2
# ..       ...                ...      ...    ...                 ...
# 402  Samsung   Galaxy Note20 5G      128      8            12+64+12
# 403   Xiaomi      Mi 10 Lite 5G      128      6            48+8+2+2
# 404    Apple  iPhone 12 Pro Max      128      6            12+12+12
# 405     Oppo              Reno3      128      8           48+13+8+2
# 406  Samsung    Galaxy S10 Lite      128      6             48+12+5
#
#      Battery Capacity (mAh) Price ($)  screen_size(inches)
# 0                      3095       999                 6.10
# ...

# %%
df['screen_size(inches)'].unique()
# Out:
# array([6.1 , 6.8 , 6.7 , 6.67, 6.4 , 6.55, 6.78, 6.43, 6.5 , 6.62, 5.4 ,
#        6.2 , 6.51, 6.6 , 4.7 , 6.58, 6.52, 6.44, 6.53, 6.56, 4.5 , 6.39,
#        5.9 , 5.5 , 6.81, 5.99, 6.82, 6.3 , 6.22, 6.  , 6.35, 6.9 , 6.76,
#        6.49, 6.72, 5.7 , 6.47, 7.6 , 6.15, 6.57])

# %%
df['Storage '].unique()
# Out:
# array(['128 GB', '256 GB', '64 GB', '32 GB', '128GB', '256GB', '64GB',
#        '32GB', '256', '64', '128', '512', '32'], dtype=object)

# %%
df['storage'] = df['Storage '].apply(lambda x : int(x.split('G')[0]))
df = df.drop('Storage ', axis='columns')
df
# Out:
#        Brand              Model   RAM          Camera (MP)  \
# 0      Apple      iPhone 13 Pro   6 GB        12 + 12 + 12
# 1    Samsung   Galaxy S21 Ultra  12 GB  108 + 10 + 10 + 12
# 2    OnePlus              9 Pro   8 GB     48 + 50 + 8 + 2
# 3     Xiaomi  Redmi Note 10 Pro   6 GB      64 + 8 + 5 + 2
# 4     Google            Pixel 6   8 GB           50 + 12.2
# ..       ...                ...    ...                 ...
# 402  Samsung   Galaxy Note20 5G      8            12+64+12
# 403   Xiaomi      Mi 10 Lite 5G      6            48+8+2+2
# 404    Apple  iPhone 12 Pro Max      6            12+12+12
# 405     Oppo              Reno3      8           48+13+8+2
# 406  Samsung    Galaxy S10 Lite      6             48+12+5
#
#      Battery Capacity (mAh) Price ($)  screen_size(inches)  storage
# 0                      3095       999                 6.10      128
# 1                      5000      1199                 6.80      256
# ...

# %%
df['storage'].unique()
# Out:
# array([128, 256,  64,  32, 512], dtype=int64)

# %%
df['RAM '].unique()
# Out:
# array(['6 GB', '12 GB', '8 GB', '4 GB', '3 GB', '2 GB', '4GB', '8GB',
#        '6GB', '12GB', '3GB', '2GB', '5GB', '12', '3', '6', '8', '4', '16',
#        '2'], dtype=object)

# %%
df['RAM'] = df['RAM '].apply(lambda x : int(x.split('G')[0]))
df = df.drop('RAM ', axis='columns')
df
# Out:
#        Brand              Model         Camera (MP)  Battery Capacity (mAh)  \
# 0      Apple      iPhone 13 Pro        12 + 12 + 12                    3095
# 1    Samsung   Galaxy S21 Ultra  108 + 10 + 10 + 12                    5000
# 2    OnePlus              9 Pro     48 + 50 + 8 + 2                    4500
# 3     Xiaomi  Redmi Note 10 Pro      64 + 8 + 5 + 2                    5020
# 4     Google            Pixel 6           50 + 12.2                    4614
# ..       ...                ...                 ...                     ...
# 402  Samsung   Galaxy Note20 5G            12+64+12                    4300
# 403   Xiaomi      Mi 10 Lite 5G            48+8+2+2                    4160
# 404    Apple  iPhone 12 Pro Max            12+12+12                    3687
# 405     Oppo              Reno3           48+13+8+2                    4025
# 406  Samsung    Galaxy S10 Lite             48+12+5                    4500
#
#     Price ($)  screen_size(inches)  storage  RAM
# ...

# %%
df['RAM'].unique()
# Out:
# array([ 6, 12,  8,  4,  3,  2,  5, 16], dtype=int64)

# %%
df['Camera (MP)'].unique()
# Out:
# array(['12 + 12 + 12', '108 + 10 + 10 + 12', '48 + 50 + 8 + 2',
#        '64 + 8 + 5 + 2', '50 + 12.2', '12 + 12', '48 + 8 + 2 + 2',
#        '50 + 13 + 16 + 2', '50 + 48 + 12 + 8', '64 + 8 + 2',
#        '64 + 12 + 5 + 5', '50 + 50 + 13 + 3', '64 + 8 + 5',
#        '64 + 12 + 12', '50 + 2 + 2', '48 + 2 + 2', '50 + 8 + 2 + 2',
#        '48 + 5', '48 + 50 + 2', '108 + 8 + 5 + 2', '13 + 2 + 2', '13 + 2',
#        '12', '48 + 5 + 2', '50 + 8 + 2', '64 + 8 + 2 + 2', '48 + 8 + 5',
#        '64 + 8', '48 + 5 + 2 + 2', '50 + 2', '64 + 12 + 8 + 5', '64 + 2',
#        '48 + 13 + 13', '12MP + 12MP', '64MP + 12MP + 12MP',
#        '50MP + 8MP + 2MP', '50MP + 12MP', '48MP + 8MP + 2MP + 2MP',
#        '64MP + 8MP + 2MP', '50MP + 48MP + 12MP + 8MP',
#        '50MP + 16MP + 13MP + 2MP', '108MP + 16MP + 8MP', '48MP + 13MP',
#        '12MP + 12MP + 12MP', '64MP + 13MP + 12MP', '64MP + 12MP + 8MP',
#        '13MP + 5MP', '64MP + 12MP + 8MP + 5MP', '108MP + 8MP + 5MP + 2MP',
# ...

# %%
def normalize_camera_mp(value):
    # Extract all numbers using regex
    numbers = re.findall(r'\d+', value)
    # Join numbers with ' + ' and return
    return ' + '.join(numbers)

# %%
import re

df['Camera (MP)'] = df['Camera (MP)'].apply(normalize_camera_mp)
df
# Out:
#        Brand              Model         Camera (MP)  Battery Capacity (mAh)  \
# 0      Apple      iPhone 13 Pro        12 + 12 + 12                    3095
# 1    Samsung   Galaxy S21 Ultra  108 + 10 + 10 + 12                    5000
# 2    OnePlus              9 Pro     48 + 50 + 8 + 2                    4500
# 3     Xiaomi  Redmi Note 10 Pro      64 + 8 + 5 + 2                    5020
# 4     Google            Pixel 6         50 + 12 + 2                    4614
# ..       ...                ...                 ...                     ...
# 402  Samsung   Galaxy Note20 5G        12 + 64 + 12                    4300
# 403   Xiaomi      Mi 10 Lite 5G      48 + 8 + 2 + 2                    4160
# 404    Apple  iPhone 12 Pro Max        12 + 12 + 12                    3687
# 405     Oppo              Reno3     48 + 13 + 8 + 2                    4025
# 406  Samsung    Galaxy S10 Lite         48 + 12 + 5                    4500
#
#     Price ($)  screen_size(inches)  storage  RAM
# ...

# %%
df['Camera (MP)'].unique()
# Out:
# array(['12 + 12 + 12', '108 + 10 + 10 + 12', '48 + 50 + 8 + 2',
#        '64 + 8 + 5 + 2', '50 + 12 + 2', '12 + 12', '48 + 8 + 2 + 2',
#        '50 + 13 + 16 + 2', '50 + 48 + 12 + 8', '64 + 8 + 2',
#        '64 + 12 + 5 + 5', '50 + 50 + 13 + 3', '64 + 8 + 5',
#        '64 + 12 + 12', '50 + 2 + 2', '48 + 2 + 2', '50 + 8 + 2 + 2',
#        '48 + 5', '48 + 50 + 2', '108 + 8 + 5 + 2', '13 + 2 + 2', '13 + 2',
#        '12', '48 + 5 + 2', '50 + 8 + 2', '64 + 8 + 2 + 2', '48 + 8 + 5',
#        '64 + 8', '48 + 5 + 2 + 2', '50 + 2', '64 + 12 + 8 + 5', '64 + 2',
#        '48 + 13 + 13', '50 + 12', '50 + 16 + 13 + 2', '108 + 16 + 8',
#        '48 + 13', '64 + 13 + 12', '64 + 12 + 8', '13 + 5', '108 + 8 + 2',
#        '64 + 5 + 2 + 2', '64 + 12', '48 + 50 + 8', '50 + 48 + 48',
#        '8 + 2', '12 + 12 + 8', '64 + 13 + 5', '12 + 13', '64 + 8 + 5 + 5',
#        '48 + 8 + 2', '48 + 2', '108 + 12 + 10 + 10', '50 + 5',
#        '48 + 8 + 5 + 5', '108 + 8 + 2 + 2', '13', '48 + 8 + 5 + 2',
# ...

# %%
def extract_camera_specs(value):
    # Extract all numbers using regex
    numbers = re.findall(r'\d+', value)
    # Convert to integers
    numbers = list(map(int, numbers))
    return numbers

# %%
df['Camera Specs'] = df['Camera (MP)'].apply(extract_camera_specs)
df
# Out:
#        Brand              Model         Camera (MP)  Battery Capacity (mAh)  \
# 0      Apple      iPhone 13 Pro        12 + 12 + 12                    3095
# 1    Samsung   Galaxy S21 Ultra  108 + 10 + 10 + 12                    5000
# 2    OnePlus              9 Pro     48 + 50 + 8 + 2                    4500
# 3     Xiaomi  Redmi Note 10 Pro      64 + 8 + 5 + 2                    5020
# 4     Google            Pixel 6         50 + 12 + 2                    4614
# ..       ...                ...                 ...                     ...
# 402  Samsung   Galaxy Note20 5G        12 + 64 + 12                    4300
# 403   Xiaomi      Mi 10 Lite 5G      48 + 8 + 2 + 2                    4160
# 404    Apple  iPhone 12 Pro Max        12 + 12 + 12                    3687
# 405     Oppo              Reno3     48 + 13 + 8 + 2                    4025
# 406  Samsung    Galaxy S10 Lite         48 + 12 + 5                    4500
#
# ...

# %%
max_cameras = df['Camera Specs'].apply(len).max()
df['cam_specs'] = df['Camera Specs'].apply(len)
max_cameras
# Out:
# 5

# %%
df
# Out:
#        Brand              Model         Camera (MP)  Battery Capacity (mAh)  \
# 0      Apple      iPhone 13 Pro        12 + 12 + 12                    3095
# 1    Samsung   Galaxy S21 Ultra  108 + 10 + 10 + 12                    5000
# 2    OnePlus              9 Pro     48 + 50 + 8 + 2                    4500
# 3     Xiaomi  Redmi Note 10 Pro      64 + 8 + 5 + 2                    5020
# 4     Google            Pixel 6         50 + 12 + 2                    4614
# ..       ...                ...                 ...                     ...
# 402  Samsung   Galaxy Note20 5G        12 + 64 + 12                    4300
# 403   Xiaomi      Mi 10 Lite 5G      48 + 8 + 2 + 2                    4160
# 404    Apple  iPhone 12 Pro Max        12 + 12 + 12                    3687
# 405     Oppo              Reno3     48 + 13 + 8 + 2                    4025
# 406  Samsung    Galaxy S10 Lite         48 + 12 + 5                    4500
#
# ...

# %%
for i in range(max_cameras):
    df[f'cam_{i+1}'] = df['Camera Specs'].apply(lambda x: x[i] if i < len(x) else None)

# %%
df = df.drop(['Camera Specs', 'Camera (MP)'], axis='columns')
df
# Out:
#        Brand              Model  Battery Capacity (mAh) Price ($)  \
# 0      Apple      iPhone 13 Pro                    3095       999
# 1    Samsung   Galaxy S21 Ultra                    5000      1199
# 2    OnePlus              9 Pro                    4500       899
# 3     Xiaomi  Redmi Note 10 Pro                    5020       279
# 4     Google            Pixel 6                    4614       799
# ..       ...                ...                     ...       ...
# 402  Samsung   Galaxy Note20 5G                    4300      1049
# 403   Xiaomi      Mi 10 Lite 5G                    4160       349
# 404    Apple  iPhone 12 Pro Max                    3687      1099
# 405     Oppo              Reno3                    4025       429
# 406  Samsung    Galaxy S10 Lite                    4500       649
#
#      screen_size(inches)  storage  RAM  cam_specs  cam_1  cam_2  cam_3  cam_4  \
# 0                   6.10      128    6          3     12   12.0   12.0    NaN
# ...

# %%
def camna(df1):
    for i in range(max_cameras):
        print(df1[f"cam_{i+1}"].isna().sum())

# %%
camna(df)
# Out:
# 0
# 9
# 76
# 258
# 406

# %%
df['cam_2'] = df['cam_2'].fillna(0)
df['cam_2'].isna().sum()
# Out:
# 0

# %%
df['cam_3'] = df['cam_3'].fillna(0)
df['cam_3'].isna().sum()
# Out:
# 0

# %%
df['cam_4'] = df['cam_4'].fillna(0)
df['cam_4'].isna().sum()
# Out:
# 0

# %%
df['cam_5'] = df['cam_5'].fillna(0)
df['cam_5'].isna().sum()
# Out:
# 0

# %%
camna(df)
# Out:
# 0
# 0
# 0
# 0
# 0

# %%
df
# Out:
#        Brand              Model  Battery Capacity (mAh) Price ($)  \
# 0      Apple      iPhone 13 Pro                    3095       999
# 1    Samsung   Galaxy S21 Ultra                    5000      1199
# 2    OnePlus              9 Pro                    4500       899
# 3     Xiaomi  Redmi Note 10 Pro                    5020       279
# 4     Google            Pixel 6                    4614       799
# ..       ...                ...                     ...       ...
# 402  Samsung   Galaxy Note20 5G                    4300      1049
# 403   Xiaomi      Mi 10 Lite 5G                    4160       349
# 404    Apple  iPhone 12 Pro Max                    3687      1099
# 405     Oppo              Reno3                    4025       429
# 406  Samsung    Galaxy S10 Lite                    4500       649
#
#      screen_size(inches)  storage  RAM  cam_specs  cam_1  cam_2  cam_3  cam_4  \
# 0                   6.10      128    6          3     12   12.0   12.0    0.0
# ...

# %%
df['Battery Capacity (mAh)'].unique()
# Out:
# array([3095, 5000, 4500, 5020, 4614, 2815, 3300, 5160, 2227, 4250, 4000,
#        4310, 6000, 3110, 1821, 2942, 4520, 3969, 4352, 4200, 4600, 4300,
#        4450, 4630, 3000, 3500, 4950, 5050, 4820, 7000, 4230, 4470, 4100,
#        4080, 4400, 4350, 3885, 4850, 2800, 4510, 3174, 2691, 4800, 4115,
#        3340, 4160, 3687, 4025], dtype=int64)

# %%
df['Price ($)'].unique()
# Out:
# array(['999', '1199', '899', '279', '799', '249', '699', '329', '449',
#        '199', '299', '379', '179', '729', '599', '139', '189', '399',
#        '259', '159', '229', '499', '129', '529', '369', '1099', '169',
#        '99', '459', '239', '1299', '429', '659', '269', '359', '$799 ',
#        '$399 ', '$699 ', '$329 ', '$999 ', '$549 ', '$1,299 ', '$899 ',
#        '$449 ', '$319 ', '$269 ', '$349 ', '$279 ', '$249 ', '$299 ',
#        '$969 ', '$1,199 ', '$149 ', '$139 ', '$99 ', '$199 ', '$169 ',
#        '$499 ', '$179 ', '$219 ', '$229 ', '$239 ', '$109 ', '$189 ',
#        '$389 ', '$309 ', '$369 ', '$129 ', '$849 ', '$469 ', '$209 ',
#        '$119 ', '$339 ', '$429 ', '$159 ', '$379 ', '$289 ', '130', '749',
#        '149', '969', '649', '349', '419', '1399', '1999', '119', '319',
#        '1049'], dtype=object)

# %%
def extract_price(value):
    # Remove the dollar sign, comma, and any leading/trailing spaces, then convert to integer
    return int(value.replace('$', '').replace(',', '').strip())

# %%
df['price'] = df['Price ($)'].apply(extract_price)
df = df.drop('Price ($)', axis='columns')

# %%
df['price'].unique()
# Out:
# array([ 999, 1199,  899,  279,  799,  249,  699,  329,  449,  199,  299,
#         379,  179,  729,  599,  139,  189,  399,  259,  159,  229,  499,
#         129,  529,  369, 1099,  169,   99,  459,  239, 1299,  429,  659,
#         269,  359,  549,  319,  349,  969,  149,  219,  109,  389,  309,
#         849,  469,  209,  119,  339,  289,  130,  749,  649,  419, 1399,
#        1999, 1049], dtype=int64)

# %%
df
# Out:
#        Brand              Model  Battery Capacity (mAh)  screen_size(inches)  \
# 0      Apple      iPhone 13 Pro                    3095                 6.10
# 1    Samsung   Galaxy S21 Ultra                    5000                 6.80
# 2    OnePlus              9 Pro                    4500                 6.70
# 3     Xiaomi  Redmi Note 10 Pro                    5020                 6.67
# 4     Google            Pixel 6                    4614                 6.40
# ..       ...                ...                     ...                  ...
# 402  Samsung   Galaxy Note20 5G                    4300                 6.70
# 403   Xiaomi      Mi 10 Lite 5G                    4160                 6.57
# 404    Apple  iPhone 12 Pro Max                    3687                 6.70
# 405     Oppo              Reno3                    4025                 6.40
# 406  Samsung    Galaxy S10 Lite                    4500                 6.70
#
# ...

# %%
usd_to_inr_rate = 83.77
df['price(inr)'] = df['price'] * usd_to_inr_rate
df = df.drop('price', axis='columns')

# %%
df['price(inr)'].unique()
# Out:
# array([ 83686.23, 100440.23,  75309.23,  23371.83,  66932.23,  20858.73,
#         58555.23,  27560.33,  37612.73,  16670.23,  25047.23,  31748.83,
#         14994.83,  61068.33,  50178.23,  11644.03,  15832.53,  33424.23,
#         21696.43,  13319.43,  19183.33,  41801.23,  10806.33,  44314.33,
#         30911.13,  92063.23,  14157.13,   8293.23,  38450.43,  20021.03,
#        108817.23,  35937.33,  55204.43,  22534.13,  30073.43,  45989.73,
#         26722.63,  29235.73,  81173.13,  12481.73,  18345.63,   9130.93,
#         32586.53,  25884.93,  71120.73,  39288.13,  17507.93,   9968.63,
#         28398.03,  24209.53,  10890.1 ,  62743.73,  54366.73,  35099.63,
#        117194.23, 167456.23,  87874.73])

# %%
df['Brand'].unique()
# Out:
# array(['Apple', 'Samsung', 'OnePlus', 'Xiaomi', 'Google', 'Oppo', 'Vivo',
#        'Realme', 'Motorola', 'Nokia', 'Sony', 'LG', 'Asus', 'Blackberry',
#        'CAT', 'Huawei'], dtype=object)

# %%
len(df['Brand'].unique())
# Out:
# 16

# %%
df["Model"].unique()
# Out:
# array(['iPhone 13 Pro', 'Galaxy S21 Ultra', '9 Pro', 'Redmi Note 10 Pro',
#        'Pixel 6', 'iPhone 13', 'Galaxy Z Flip3', 'Poco X3 Pro',
#        'Reno6 Pro+ 5G', 'X70 Pro+', 'Nord CE 5G', 'Galaxy A52s 5G',
#        'GT Neo2', 'iPhone 12 Mini', 'Find X3 Pro', 'Mi 11 Lite 5G NE',
#        'Galaxy S21', 'Y20s (G)', '8s 5G', 'A94', 'Redmi 10 Prime',
#        'Galaxy A22 5G', 'Narzo 50 Pro 5G', '9', 'Redmi Note 10 Pro Max',
#        'iPhone 11', 'Galaxy A03s', 'A74 5G', 'Y12s (2021)', '9i',
#        'Galaxy M52 5G', 'Redmi 10', 'iPhone SE (2nd Gen)', 'A53s', 'Y33s',
#        'C25s', 'Galaxy A22 4G', 'Nord 2 5G', 'Poco M3 Pro 5G',
#        'iPhone XR', 'A16', 'C21Y', 'Galaxy F22', 'F19 Pro+ 5G', 'Mi 11X',
#        'V21e', '8 5G', 'Galaxy M12', 'A16s', 'Redmi 9 Power',
#        'iPhone 11 Pro Max', 'Y20G', 'Narzo 50i', 'A54', 'Redmi 9T',
#        'iPhone 13 Pro Max', 'Y33', 'Galaxy A72', 'Reno6 Pro 5G',
#        'iPhone SE (2020)', 'Y53s', '7i', 'Galaxy A52 5G', 'F19 Pro',
# ...

# %%
len(df['Model'].unique())
# Out:
# 239

# %%
df.duplicated().sum()
# Out:
# 49

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (358, 13)

# %%
Q1 = df['price(inr)'].quantile(0.25)
Q3 = df['price(inr)'].quantile(0.75)

# %%
IQR = Q3 - Q1

# %%
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# %%
df.loc[:, 'Outlier'] = (df['price(inr)'] < lower_bound) | (df['price(inr)'] > upper_bound)

# %%
df
# Out:
#        Brand              Model  Battery Capacity (mAh)  screen_size(inches)  \
# 0      Apple      iPhone 13 Pro                    3095                 6.10
# 1    Samsung   Galaxy S21 Ultra                    5000                 6.80
# 2    OnePlus              9 Pro                    4500                 6.70
# 3     Xiaomi  Redmi Note 10 Pro                    5020                 6.67
# 4     Google            Pixel 6                    4614                 6.40
# ..       ...                ...                     ...                  ...
# 401   Huawei           P30 Lite                    3340                 6.15
# 402  Samsung   Galaxy Note20 5G                    4300                 6.70
# 403   Xiaomi      Mi 10 Lite 5G                    4160                 6.57
# 404    Apple  iPhone 12 Pro Max                    3687                 6.70
# 405     Oppo              Reno3                    4025                 6.40
#
# ...

# %%
len(df[df['Outlier']])
# Out:
# 36

# %%
df[df['Outlier']]
# Out:
#        Brand                 Model  Battery Capacity (mAh)  \
# 0      Apple         iPhone 13 Pro                    3095
# 1    Samsung      Galaxy S21 Ultra                    5000
# 6    Samsung        Galaxy Z Flip3                    3300
# 9       Vivo              X70 Pro+                    4500
# 14      Oppo           Find X3 Pro                    4500
# 51     Apple     iPhone 11 Pro Max                    3969
# 57     Apple     iPhone 13 Pro Max                    4352
# 83      Vivo              X70 Pro+                    4450
# 87      Sony          Xperia 5 III                    4500
# 88        LG                  Wing                    4000
# 102  Samsung       Galaxy Z Flip 3                    3300
# 103  OnePlus                 9 Pro                    4500
# 104   Xiaomi           Mi 11 Ultra                    5000
# 112     Asus           ROG Phone 5                    6000
# 148  Samsung   Galaxy S21 Ultra 5G                    5000
# ...

# %%
df2 = df.drop(['Brand', 'Model', 'Outlier', 'cam_specs'], axis='columns')
df2
# Out:
#      Battery Capacity (mAh)  screen_size(inches)  storage  RAM  cam_1  cam_2  \
# 0                      3095                 6.10      128    6     12   12.0
# 1                      5000                 6.80      256   12    108   10.0
# 2                      4500                 6.70      128    8     48   50.0
# 3                      5020                 6.67      128    6     64    8.0
# 4                      4614                 6.40      128    8     50   12.0
# ..                      ...                  ...      ...  ...    ...    ...
# 401                    3340                 6.15      128    4     48    8.0
# 402                    4300                 6.70      128    8     12   64.0
# 403                    4160                 6.57      128    6     48    8.0
# 404                    3687                 6.70      128    6     12   12.0
# 405                    4025                 6.40      128    8     48   13.0
#
#      cam_3  cam_4  cam_5  price(inr)
# ...

# %%
df2.duplicated().sum()
# Out:
# 25

# %%
df2 = df2.drop_duplicates()

# %%
df2.shape
# Out:
# (333, 10)

# %%
df2.tail()
# Out:
#      Battery Capacity (mAh)  screen_size(inches)  storage  RAM  cam_1  cam_2  \
# 401                    3340                 6.15      128    4     48    8.0
# 402                    4300                 6.70      128    8     12   64.0
# 403                    4160                 6.57      128    6     48    8.0
# 404                    3687                 6.70      128    6     12   12.0
# 405                    4025                 6.40      128    8     48   13.0
#
#      cam_3  cam_4  cam_5  price(inr)
# 401    2.0    0.0    0.0    27560.33
# 402   12.0    0.0    0.0    87874.73
# 403    2.0    2.0    0.0    29235.73
# 404   12.0    0.0    0.0    92063.23
# 405    8.0    2.0    0.0    35937.33

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import numpy as np

# %%
df1 = df.drop(['cam_specs', 'Outlier', 'Model'], axis='columns')
df1 = pd.concat([df1, pd.get_dummies(df['Brand'])], axis='columns')
df1 = df1.drop('Brand', axis='columns')
df1
# Out:
#      Battery Capacity (mAh)  screen_size(inches)  storage  RAM  cam_1  cam_2  \
# 0                      3095                 6.10      128    6     12   12.0
# 1                      5000                 6.80      256   12    108   10.0
# 2                      4500                 6.70      128    8     48   50.0
# 3                      5020                 6.67      128    6     64    8.0
# 4                      4614                 6.40      128    8     50   12.0
# ..                      ...                  ...      ...  ...    ...    ...
# 401                    3340                 6.15      128    4     48    8.0
# 402                    4300                 6.70      128    8     12   64.0
# 403                    4160                 6.57      128    6     48    8.0
# 404                    3687                 6.70      128    6     12   12.0
# 405                    4025                 6.40      128    8     48   13.0
#
# ...

# %%
def pred(brandname,bat_cap,screensize,strg,ram,c1,c2,c3,c4,c5):
    x_loc = np.where(x.columns==brandname)[0][0]
    x_new = np.full(len(x.columns), False, dtype=bool)
    x_new[0] = bat_cap
    x_new[1] = screensize
    x_new[2] = strg
    x_new[3] = ram
    x_new[4] = c1
    x_new[5] = c2
    x_new[6] = c3
    x_new[7] = c4
    x_new[8] = c5
    if x_loc >= 0:
        x_new[x_loc] = True

    return(model.predict([x_new])[0])

# %%
from sklearn.linear_model import Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import GridSearchCV

# %%
def bestmodel(x,y):
    models = {'LinearRegression':{'model':LinearRegression(), 'params':{'fit_intercept': [True, False],'copy_X': [True, False],'positive': [True, False]}},
              'Lasso':{'model':Lasso(), 'params':{'alpha':[1,2], 'selection':['random','cyclic']}},
              'DecisionTreeRegressor':{'model':DecisionTreeRegressor(), 'params':{'criterion':['mse','friedman_mse'], 'splitter':['best','random']}}}

    cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)
    scores = []
    for i,j in models.items():
        clf = GridSearchCV(j['model'], j['params'], cv=cv, return_train_score=False)
        clf.fit(x,y)
        scores.append({'model':i, 'best_score':clf.best_score_, 'best_params':clf.best_params_})

    return(pd.DataFrame(scores, columns=['model', 'best_score', 'best_params']))

# %%
x0 = df2.drop('price(inr)', axis='columns')
y0 = df2['price(inr)']

# %%
import warnings
warnings.filterwarnings("ignore")

bestmodel(x0,y0)
# Out:
#                    model  best_score  \
# 0       LinearRegression    0.707157
# 1                  Lasso    0.701291
# 2  DecisionTreeRegressor    0.857859
#
#                                          best_params
# 0  {'copy_X': True, 'fit_intercept': False, 'posi...
# 1                {'alpha': 2, 'selection': 'random'}
# 2  {'criterion': 'friedman_mse', 'splitter': 'best'}

# %%
x_train, x_test, y_train, y_test = train_test_split(x0,y0,test_size=0.2)

model = DecisionTreeRegressor(criterion='friedman_mse', splitter='best')
model.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(criterion='friedman_mse')

# %%
import pickle
with open('model.pickle', 'rb') as f:
        mymodel = pickle.load(f)

# %%
y_pred = mymodel.predict(x_test)

# %%
model.score(x_test, y_test)
# Out:
# 0.8526793606873643

# %%
model.score(x_train, y_train)
# Out:
# 0.9966260998165324

# %%
df2['price(inr)'].min()
# Out:
# 8293.23

# %%
df2['price(inr)'].max()
# Out:
# 167456.22999999998

# %%
from sklearn.metrics import mean_absolute_error, r2_score

mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# %%
mae
# Out:
# 1800.4298507462688

# %%
r2
# Out:
# 0.9775909834994053

# %%
model.predict([[4500, 6.7, 256, 12, 48, 8, 50, 2, 16]])
# Out:
# array([58555.23])

# %%
model.predict([[5000, 6.8, 128, 12, 108, 10, 10, 12, 40]])
# Out:
# array([100440.23])

# %%
def adjust_price(predicted_price, release_year, days_used, current_year=2024):
    # Depreciation rates (example values)
    yearly_depreciation_rate = 0.10  # 10% per year
    daily_depreciation_rate = 0.0002  # 0.02% per day
    
    # Calculate the age of the phone
    age_in_years = current_year - release_year
    
    # Calculate the depreciation factors
    year_depreciation = 1 - (age_in_years * yearly_depreciation_rate)
    day_depreciation = 1 - (days_used * daily_depreciation_rate)
    
    # Adjust the predicted price
    adjusted_price = predicted_price * year_depreciation * day_depreciation
    
    # Ensure the price doesn't go below zero
    return max(10000, adjusted_price)

# %%
predicted_price = model.predict([[5000, 6.8, 128, 12, 108, 10, 10, 12, 40]])[0]
final_price = adjust_price(predicted_price, 2019, 190)

# %%
final_price
# Out:
# 48311.750629999995

# %%
model.predict([[5000, 6.8, 128, 12, 108, 12, 10, 10, 0]])[0]
# Out:
# 100440.23

# %%
predicted_price = model.predict([[5000, 6.8, 128, 12, 108, 12, 10, 10, 0]])[0]
final_price = adjust_price(predicted_price, 2021, 865)

# %%
final_price
# Out:
# 58144.84914699999

# %%
df2['Battery Capacity (mAh)'].describe()
# Out:
# count     333.000000
# mean     4699.561562
# std       779.392751
# min      1821.000000
# 25%      4300.000000
# 50%      5000.000000
# 75%      5000.000000
# max      7000.000000
# Name: Battery Capacity (mAh), dtype: float64

# %%
df2['screen_size(inches)'].describe()
# Out:
# count    333.000000
# mean       6.484775
# std        0.296406
# min        4.500000
# 25%        6.440000
# 50%        6.500000
# 75%        6.600000
# max        7.600000
# Name: screen_size(inches), dtype: float64

# %%
df2['storage'].describe()
# Out:
# count    333.000000
# mean     125.693694
# std       69.326987
# min       32.000000
# 25%       64.000000
# 50%      128.000000
# 75%      128.000000
# max      512.000000
# Name: storage, dtype: float64

# %%
df2['RAM'].describe()
# Out:
# count    333.000000
# mean       5.930931
# std        2.536131
# min        2.000000
# 25%        4.000000
# 50%        6.000000
# 75%        8.000000
# max       16.000000
# Name: RAM, dtype: float64

# %%
df2['cam_1'].describe()
# Out:
# count    333.000000
# mean      43.261261
# std       24.868102
# min        8.000000
# 25%       13.000000
# 50%       48.000000
# 75%       64.000000
# max      108.000000
# Name: cam_1, dtype: float64

# %%
df2['cam_2'].describe()
# Out:
# count    333.000000
# mean       9.297297
# std       10.807400
# min        0.000000
# 25%        2.000000
# 50%        8.000000
# 75%       12.000000
# max       64.000000
# Name: cam_2, dtype: float64

# %%
df2['cam_3'].describe()
# Out:
# count    333.000000
# mean       3.966967
# std        5.367415
# min        0.000000
# 25%        2.000000
# 50%        2.000000
# 75%        5.000000
# max       48.000000
# Name: cam_3, dtype: float64

# %%
df2['cam_4'].describe()
# Out:
# count    333.000000
# mean       0.951952
# std        1.636584
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        2.000000
# max       12.000000
# Name: cam_4, dtype: float64

# %%
df2['cam_5'].describe()
# Out:
# count    333.000000
# mean       0.009009
# std        0.164399
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        3.000000
# Name: cam_5, dtype: float64

# %%
df_scaled = df2.copy()

# %%
df_scaled
# Out:
#      Battery Capacity (mAh)  screen_size(inches)  storage  RAM  cam_1  cam_2  \
# 0                      3095                 6.10      128    6     12   12.0
# 1                      5000                 6.80      256   12    108   10.0
# 2                      4500                 6.70      128    8     48   50.0
# 3                      5020                 6.67      128    6     64    8.0
# 4                      4614                 6.40      128    8     50   12.0
# ..                      ...                  ...      ...  ...    ...    ...
# 401                    3340                 6.15      128    4     48    8.0
# 402                    4300                 6.70      128    8     12   64.0
# 403                    4160                 6.57      128    6     48    8.0
# 404                    3687                 6.70      128    6     12   12.0
# 405                    4025                 6.40      128    8     48   13.0
#
#      cam_3  cam_4  cam_5  price(inr)
# ...

# %%
df_scaled_x = df_scaled.drop('price(inr)', axis='columns')
df_scaled_x
# Out:
#      Battery Capacity (mAh)  screen_size(inches)  storage  RAM  cam_1  cam_2  \
# 0                      3095                 6.10      128    6     12   12.0
# 1                      5000                 6.80      256   12    108   10.0
# 2                      4500                 6.70      128    8     48   50.0
# 3                      5020                 6.67      128    6     64    8.0
# 4                      4614                 6.40      128    8     50   12.0
# ..                      ...                  ...      ...  ...    ...    ...
# 401                    3340                 6.15      128    4     48    8.0
# 402                    4300                 6.70      128    8     12   64.0
# 403                    4160                 6.57      128    6     48    8.0
# 404                    3687                 6.70      128    6     12   12.0
# 405                    4025                 6.40      128    8     48   13.0
#
#      cam_3  cam_4  cam_5
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
df_scaled_x = pd.DataFrame(scaler.fit_transform(df_scaled_x), columns=df_scaled_x.columns)

# %%
df_scaled_x
# Out:
#      Battery Capacity (mAh)  screen_size(inches)   storage       RAM  cam_1  \
# 0                  0.245993             0.516129  0.200000  0.285714   0.04
# 1                  0.613825             0.741935  0.466667  0.714286   1.00
# 2                  0.517281             0.709677  0.200000  0.428571   0.40
# 3                  0.617687             0.700000  0.200000  0.285714   0.56
# 4                  0.539293             0.612903  0.200000  0.428571   0.42
# ..                      ...                  ...       ...       ...    ...
# 328                0.293300             0.532258  0.200000  0.142857   0.40
# 329                0.478664             0.709677  0.200000  0.428571   0.04
# 330                0.451632             0.667742  0.200000  0.285714   0.40
# 331                0.360301             0.709677  0.200000  0.285714   0.04
# 332                0.425565             0.612903  0.200000  0.428571   0.40
#
#         cam_2     cam_3     cam_4  cam_5
# ...

# %%
df_scaled_y = pd.DataFrame(df_scaled['price(inr)'])

# %%
df_scaled_y
# Out:
#      price(inr)
# 0      83686.23
# 1     100440.23
# 2      75309.23
# 3      23371.83
# 4      66932.23
# ..          ...
# 401    27560.33
# 402    87874.73
# 403    29235.73
# 404    92063.23
# 405    35937.33
#
# [333 rows x 1 columns]

# %%
# Reset the index for both DataFrames to make sure they align
df_scaled_x.reset_index(drop=True, inplace=True)
df_scaled_y.reset_index(drop=True, inplace=True)

# %%
df_scaled_x
# Out:
#      Battery Capacity (mAh)  screen_size(inches)   storage       RAM  cam_1  \
# 0                  0.245993             0.516129  0.200000  0.285714   0.04
# 1                  0.613825             0.741935  0.466667  0.714286   1.00
# 2                  0.517281             0.709677  0.200000  0.428571   0.40
# 3                  0.617687             0.700000  0.200000  0.285714   0.56
# 4                  0.539293             0.612903  0.200000  0.428571   0.42
# ..                      ...                  ...       ...       ...    ...
# 328                0.293300             0.532258  0.200000  0.142857   0.40
# 329                0.478664             0.709677  0.200000  0.428571   0.04
# 330                0.451632             0.667742  0.200000  0.285714   0.40
# 331                0.360301             0.709677  0.200000  0.285714   0.04
# 332                0.425565             0.612903  0.200000  0.428571   0.40
#
#         cam_2     cam_3     cam_4  cam_5
# ...

# %%
df_scaled_y
# Out:
#      price(inr)
# 0      83686.23
# 1     100440.23
# 2      75309.23
# 3      23371.83
# 4      66932.23
# ..          ...
# 328    27560.33
# 329    87874.73
# 330    29235.73
# 331    92063.23
# 332    35937.33
#
# [333 rows x 1 columns]

# %%
df_scaled = pd.concat([df_scaled_x, df_scaled_y], axis='columns')

# %%
df_scaled
# Out:
#      Battery Capacity (mAh)  screen_size(inches)   storage       RAM  cam_1  \
# 0                  0.245993             0.516129  0.200000  0.285714   0.04
# 1                  0.613825             0.741935  0.466667  0.714286   1.00
# 2                  0.517281             0.709677  0.200000  0.428571   0.40
# 3                  0.617687             0.700000  0.200000  0.285714   0.56
# 4                  0.539293             0.612903  0.200000  0.428571   0.42
# ..                      ...                  ...       ...       ...    ...
# 328                0.293300             0.532258  0.200000  0.142857   0.40
# 329                0.478664             0.709677  0.200000  0.428571   0.04
# 330                0.451632             0.667742  0.200000  0.285714   0.40
# 331                0.360301             0.709677  0.200000  0.285714   0.04
# 332                0.425565             0.612903  0.200000  0.428571   0.40
#
#         cam_2     cam_3     cam_4  cam_5  price(inr)
# ...

# %%
xs = df_scaled.drop('price(inr)', axis='columns')
ys = df_scaled['price(inr)']

# %%
import warnings
warnings.filterwarnings("ignore")

bestmodel(xs,ys)
# Out:
#                    model  best_score  \
# 0       LinearRegression    0.701259
# 1                  Lasso    0.701510
# 2  DecisionTreeRegressor    0.844018
#
#                                          best_params
# 0  {'copy_X': True, 'fit_intercept': True, 'posit...
# 1                {'alpha': 2, 'selection': 'cyclic'}
# 2  {'criterion': 'friedman_mse', 'splitter': 'best'}

# %%
from sklearn.model_selection import cross_val_score

# %%
cross_val_score(DecisionTreeRegressor(criterion='friedman_mse', splitter='best'), xs, ys, cv=5)
# Out:
# array([0.77188883, 0.8568265 , 0.91961728, 0.84917064, 0.71989605])

# %%
cross_val_score(DecisionTreeRegressor(criterion='friedman_mse', splitter='best'), x0, y0, cv=5)
# Out:
# array([0.78217113, 0.84904879, 0.92112966, 0.88605128, 0.71834613])

# %%
# import pickle

# with open('model.pickle','wb') as f:
#     pickle.dump(model,f)

# %%
scaler = MinMaxScaler()

# %%
x2 = df2.drop('price(inr)',axis='columns')
y2 = df2['price(inr)']

# %%
x2 = scaler.fit_transform(x2)

# %%
# import pickle

# with open('scaler.pkl', 'wb') as f:
#     pickle.dump(scaler, f)

# %%
x2
# Out:
# array([[0.24599344, 0.51612903, 0.2       , ..., 0.25      , 0.        ,
#         0.        ],
#        [0.61382506, 0.74193548, 0.46666667, ..., 0.20833333, 1.        ,
#         0.        ],
#        [0.51728133, 0.70967742, 0.2       , ..., 0.16666667, 0.16666667,
#         0.        ],
#        ...,
#        [0.45163159, 0.66774194, 0.2       , ..., 0.04166667, 0.16666667,
#         0.        ],
#        [0.36030122, 0.70967742, 0.2       , ..., 0.25      , 0.        ,
#         0.        ],
#        [0.42556478, 0.61290323, 0.2       , ..., 0.16666667, 0.16666667,
#         0.        ]])

# %%
x2 = pd.DataFrame(x2, columns=df2.drop('price(inr)', axis='columns').columns)

# %%
x2
# Out:
#      Battery Capacity (mAh)  screen_size(inches)   storage       RAM  cam_1  \
# 0                  0.245993             0.516129  0.200000  0.285714   0.04
# 1                  0.613825             0.741935  0.466667  0.714286   1.00
# 2                  0.517281             0.709677  0.200000  0.428571   0.40
# 3                  0.617687             0.700000  0.200000  0.285714   0.56
# 4                  0.539293             0.612903  0.200000  0.428571   0.42
# ..                      ...                  ...       ...       ...    ...
# 328                0.293300             0.532258  0.200000  0.142857   0.40
# 329                0.478664             0.709677  0.200000  0.428571   0.04
# 330                0.451632             0.667742  0.200000  0.285714   0.40
# 331                0.360301             0.709677  0.200000  0.285714   0.04
# 332                0.425565             0.612903  0.200000  0.428571   0.40
#
#         cam_2     cam_3     cam_4  cam_5
# ...

# %%
xback = x2.copy()

# %%
y2.reset_index(drop=True, inplace=True)

# %%
y2
# Out:
# 0       83686.23
# 1      100440.23
# 2       75309.23
# 3       23371.83
# 4       66932.23
#          ...
# 328     27560.33
# 329     87874.73
# 330     29235.73
# 331     92063.23
# 332     35937.33
# Name: price(inr), Length: 333, dtype: float64

# %%
from sklearn.decomposition import PCA

pca = PCA(0.95)

# %%
x2 = pca.fit_transform(x2)

# %%
# import pickle

# with open('pca.pkl', 'wb') as f:
#     pickle.dump(pca, f)

# %%
x2 = pd.DataFrame(x2)

# %%
x2
# Out:
#             0         1         2         3         4         5         6
# 0   -0.233147 -0.388391 -0.147747  0.030488 -0.042705 -0.036051  0.118666
# 1    0.994900  0.166418  0.054145  0.641452 -0.327379  0.108465 -0.046571
# 2    0.333201 -0.359302  0.201916  0.065772  0.388312  0.045908  0.057756
# 3    0.176974  0.150802  0.008580  0.047652 -0.005682 -0.035616  0.021691
# 4    0.101547 -0.031104 -0.069081 -0.097908  0.031642  0.095517 -0.013776
# ..        ...       ...       ...       ...       ...       ...       ...
# 328 -0.102112 -0.040891 -0.271147  0.049597  0.096697 -0.108274 -0.026480
# 329  0.123396 -0.707929  0.343724 -0.063330  0.481959  0.047294  0.102413
# 330  0.038589  0.004154 -0.076394  0.093894 -0.010493  0.014067 -0.031904
# 331 -0.195847 -0.319514  0.004972 -0.039952 -0.070017 -0.042276  0.115128
# 332  0.141085 -0.126201 -0.086494  0.079384 -0.026669  0.059266  0.074451
#
# [333 rows x 7 columns]

# %%
x_train, x_test, y_train, y_test = train_test_split(x2,y2,test_size=0.2)

# %%
#model2 = DecisionTreeRegressor(criterion='friedman_mse', splitter='best')
model2 = LinearRegression()
model2.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
import pickle

with open('model2.pickle', 'rb') as f:
     scaledmodel = pickle.load(f)

# %%
scaledmodel.score(x_test, y_test)
# Out:
# 0.6961554078810169

# %%
scaledmodel.score(x_train, y_train)
# Out:
# 0.7704360507089094

# %%
y_pred = scaledmodel.predict(x_test)

# %%
df['price(inr)'].min()
# Out:
# 8293.23

# %%
df['price(inr)'].max()
# Out:
# 167456.22999999998

# %%
from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(y_test, y_pred)

# %%
mae
# Out:
# 11093.574810669092

# %%
model2.score(x_test,y_test)
# Out:
# 0.6386657581740665

# %%
model2.score(x_train,y_train)
# Out:
# 0.7815134915860799

# %%
 y_pred = model2.predict(x_test)

# %%
df2['price(inr)'].min()
# Out:
# 8293.23

# %%
df2['price(inr)'].max()
# Out:
# 167456.22999999998

# %%
from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(y_test, y_pred)

# %%
mae
# Out:
# 11967.446108828482

# %%
# import pickle

# with open('model2.pickle','wb') as f:
#     pickle.dump(model2,f)

# %%
# import pickle

# with open('model.pickle','wb') as f:
#     pickle.dump(model,f)

# %%
model.predict([[5000, 6.4, 128, 8, 50, 12, 5, 32, 0]])[0]
# Out:
# 35937.33

# %%
model2.predict([[-0.195847,-0.319514,0.004972,-0.039952,-0.070017,-0.042276,0.115128]])[0]
# Out:
# 57306.35870576323

# %%
# import numpy as np

# pca = PCA().fit(xback)
# cumulative_variance = np.cumsum(pca.explained_variance_ratio_)

# # Find the number of components that explain 95% of the variance
# n_components = np.argmax(cumulative_variance >= 0.95) + 1

# %%
def predictprice(battery, screen_size, storage, ram, cam1, cam2, cam3, cam4, cam5):
    import pickle
    
    with open('scaler.pkl', 'rb') as f:
     scaler = pickle.load(f)

    with open('pca.pkl', 'rb') as f:
     pca = pickle.load(f)

    with open('model2.pickle', 'rb') as f:
     model = pickle.load(f)

    # Combine the input features into a single array
    input_data = np.array([[battery, screen_size, storage, ram, cam1, cam2, cam3, cam4, cam5]])
    
    # Scale the input data
    input_scaled = scaler.transform(input_data)
    
    # Apply PCA to the scaled data
    input_pca = pca.transform(input_scaled)
    
    # Predict the price using the model
    predicted_price = model.predict(input_pca)
    
    return predicted_price[0]

# %%
import pickle

with open('model.pickle', 'rb') as f:
     nonscaledmodel = pickle.load(f)

# %%
predictprice(5000, 6.4, 128, 8, 50, 12, 5, 32, 0)
# Out:
# 37561.67980420205

# %%
nonscaledmodel.predict([[5000, 6.4, 128, 8, 50, 12, 5, 32, 0]])[0]
# Out:
# 29235.73

# %%
predictprice(3095, 6.10, 128, 6, 12, 12.0, 12.0, 0.0 ,0.0)
# Out:
# 63863.64621535022

# %%
nonscaledmodel.predict([[3095, 6.10, 128, 6, 12, 12.0, 12.0, 0.0 ,0.0]])[0]
# Out:
# 66932.23

# %%
predictprice(5000, 6.7, 256, 12, 50, 32, 48, 0, 0)
# Out:
# 128692.41030988694

# %%
nonscaledmodel.predict([[5000, 6.7, 256, 12, 50, 32, 48, 0, 0]])[0]
# Out:
# 83686.23

# %%
predictprice(4500, 6.7, 128, 8, 48, 8, 50, 2, 0)
# Out:
# 94176.61544373783

# %%
nonscaledmodel.predict([[4500, 6.7, 128, 8, 48, 8, 50, 2, 0]])[0]
# Out:
# 58555.229999999996

# %%
predictprice(5000, 6.67, 128, 8, 108, 10, 5, 0, 0)
# Out:
# 33241.27848901378

# %%
nonscaledmodel.predict([[5000, 6.67, 128, 8, 108, 10, 5, 0, 0]])[0]
# Out:
# 50178.229999999996

# %%
predictprice(4050, 6.44, 128, 8, 64, 8, 2, 0, 0)
# Out:
# 41710.68242730422

# %%
nonscaledmodel.predict([[4050, 6.44, 128, 8, 64, 8, 2, 0, 0]])[0]
# Out:
# 36356.17999999999

# %%
import pickle

with open('model.pickle', 'rb') as f:
     savedmodel = pickle.load(f)
    
importances = savedmodel.feature_importances_

# Create a dictionary mapping features to their importance
feature_names = ['battery', 'screen_size', 'storage', 'ram', 'cam1', 'cam2', 'cam3', 'cam4', 'cam5']
feature_importance_dict = dict(zip(feature_names, importances))

# Sort features by importance
sorted_importance = sorted(feature_importance_dict.items(), key=lambda x: x[1], reverse=True)

# Print the sorted importance
for feature, importance in sorted_importance:
    print(f"{feature}: {importance}")
# Out:
# cam2: 0.6019332964529045
# cam3: 0.1276915283993972
# battery: 0.07563581039331464
# screen_size: 0.0749614459761944
# ram: 0.05126320503434462
# storage: 0.042396421449648405
# cam1: 0.023114445041256395
# cam4: 0.0030038472529398523
# cam5: 0.0

# %%
import matplotlib.pyplot as plt
import numpy as np



# Plot
plt.figure(figsize=(10, 6))
plt.barh(feature_names, importances)
plt.xlabel('Importance')
plt.ylabel('Features')
plt.title('Feature Importances')
plt.show()

# %%
plt.figure(figsize=(10, 10))
plt.pie(importances, labels=feature_names, autopct='%1.1f%%', startangle=140)
plt.title('Feature Importances (Tree-Based Model)')
plt.show()

# %%
x_train, x_test, y_train, y_test = train_test_split(x0,y0,test_size=0.2)

# %%
def modscore(x,y):
    import pickle
    
    with open('model.pickle', 'rb') as f:
     model = pickle.load(f)

    return model.score(x,y)

# %%
modscore(x_train,y_train)
# Out:
# 0.9826950435115712

# %%
modscore(x_test,y_test)
# Out:
# 0.9028071177216043

# %%
def pricereport(batcap, ss, sto, ram, c1, c2, c3, c4, c5, release_year, days_used):
    import matplotlib.pyplot as plt
    import numpy as np
    import pickle
    import warnings
    warnings.filterwarnings("ignore", category=UserWarning)

    # Load the trained model
    with open('model.pickle', 'rb') as f:
        model = pickle.load(f)

    # Feature importance from the model
    feature_importances = model.feature_importances_
    feature_names = ['battery', 'screen_size', 'storage', 'ram', 'cam1', 'cam2', 'cam3', 'cam4', 'cam5']

    # Smartphone features for the given device
    smartphone_features = np.array([batcap, ss, sto, ram, c1, c2, c3, c4, c5])

    # Calculate contributions based on feature importance
    contribution = feature_importances * smartphone_features
    contribution_normalized = contribution / np.sum(contribution)

    # Create a figure with two subplots: one for the pie chart, one for the text
    fig, axs = plt.subplots(1, 2, figsize=(14, 7), gridspec_kw={'width_ratios': [1, 1]})

    # Plot pie chart of feature importance in the left subplot
    axs[0].pie(feature_importances, labels=feature_names, autopct='%1.1f%%', startangle=140)
    axs[0].set_title('Feature Importances (Tree-Based Model)')

    # Predict the price for the given smartphone features
    predicted_price = model.predict([[batcap, ss, sto, ram, c1, c2, c3, c4, c5]])[0]

    # Calculate the price contribution for each feature
    feature_price_contribution = feature_importances * predicted_price

    # Sort features based on their contribution
    sorted_contribution = sorted(zip(feature_names, feature_price_contribution), key=lambda x: x[1], reverse=True)

    # Display the price contribution on the right subplot
    axs[1].axis('off')  # Turn off the axis for the text plot
    axs[1].text(0, 1, 'Price Contribution by Feature (in descending order):', fontsize=12, weight='bold')

    y_offset = 0.9  # Starting y position for the text display
    for feature, contribution in sorted_contribution:
        axs[1].text(0, y_offset, f"{feature}: {contribution:.2f}", fontsize=10)
        y_offset -= 0.05  # Move down for the next line of text

    # Adjust the price based on release year and days used
    adjusted_price = adjust_price(predicted_price, release_year, days_used)

    # Print the depreciation due to the release year and number of days used
    year_depreciation = (2024 - release_year) * 0.10  # 10% depreciation per year
    days_depreciation = days_used * 0.0002  # 0.02% depreciation per day
    total_depreciation = predicted_price * (year_depreciation + days_depreciation)

    # Display depreciation and final adjusted price
    axs[1].text(0, y_offset - 0.05, f"\nDepreciation due to age: -{total_depreciation:.2f}", fontsize=10, color='red')
    axs[1].text(0, y_offset - 0.10, f"\nFinal Adjusted Price: {adjusted_price:.2f}", fontsize=12, color='blue')

    # Print the final predicted price
    axs[1].text(0, y_offset - 0.15, f"\nPredicted Price (Before Depreciation): {predicted_price:.2f}", fontsize=12, color='green')

    # Adjust layout and display the figure
    plt.tight_layout()
    plt.show()

# %%
pricereport(5000, 7.85, 256, 12, 50, 50, 13, 0, 0, 2023, 109)
